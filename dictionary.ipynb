# %%
mounth_dictionary = {
    1 : "jan",
    2 : "feb",
    3 : "mar",
    4 : "apr",
    5 : "may",
    6 : "jan",
    7 : "jul",
    8 : "aug",
    9 : "sep",
    10: "oct",
    11: "nov",
    12: "dec",
}
print(mounth_dictionary[2])
print(mounth_dictionary.get(3))
print(mounth_dictionary.get(32,"Not valid")) #give it a default value

i = 1
while i <=12:
    print("  " +mounth_dictionary[i])
    i += 1
print("loop end")

for letter in "Mohamed":
    print(letter)

nums = [1 , 2, 3, 4, 5, 6, 7, 8, 9, 0]    
for i in nums: # for each number in nums print it
    print(i)
friends = ["M1" , "M2" , "M3"]
for friend in friends: # for each number in nums print it
    print(friend)   
    
for i in range(5):
    print(i)
for i in range(3,10):
    print(i)    
    
for i in range(len(friends)):
    print(friends[i])
# Out:
# feb
# mar
# Not valid
#   jan
#   feb
#   mar
#   apr
#   may
#   jan
#   jul
#   aug
#   sep
#   oct
#   nov
#   dec
# loop end
# M
# o
# h
# a
# m
# e
# d
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 0
# M1
# M2
# M3
# 0
# 1
# 2
# 3
# 4
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# M1
# M2
# M3
